# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.io

# %%
# Reading mat file
mat = scipy.io.loadmat("Data/realitymining.mat")

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'network', 's'])

# %%
sensor_df = pd.DataFrame.from_dict(mat["s"][0])

# %%
sensor_df.shape
# Out:
# (106, 58)

# %%
sensor_df.describe().T
# Out:
#                   count unique  \
# comm                106    106
# charge              106    106
# active              106    106
# logtimes            106    106
# on                  106    106
# locs                106    106
# all_locs            106    106
# loc_ids             106    106
# device_names        106    106
# device_macs         106    106
# device_date         106    106
# device_list_names   106    106
# device_list_macs    106    106
# device_types        106    106
# device_list_types   106    106
# cellnames           106    106
# apps                106    106
# timeon              106    102
# app_dates           106    106
# comm_sms            106     50
# comm_sms_date       106    106
# comm_voice          106     87
# comm_voice_date     106    106
# comm_data           106     56
# comm_data_date      106    106
# surveydata          106    106
# my_mac              106    106
# my_startdate        106     48
# my_affil            106     21
# ...

# %%
sensor_df.head()
# Out:
#                                                 comm  \
# 0                                                 []
# 1  [[[[[732338.86915509]], [[354]], [[-1]], ['Pac...
# 2  [[[[[732204.80221065]], [[197]], [[-1]], ['Voi...
# 3  [[[[[732162.65994213]], [[299]], [[-1]], ['Voi...
# 4  [[[[[732150.05202546]], [[84]], [[-1]], ['Voic...
#
#                                               charge  \
# 0                                               [[]]
# 1  [[732338.7079282408, 1.0], [732338.7265856481,...
# 2  [[732179.4270370371, 1.0], [732179.4851620371,...
# 3  [[732154.9639930555, 1.0], [732155.3885300925,...
# 4  [[732150.4538541667, 1.0], [732150.5684837963,...
#
#                                               active  \
# 0                                               [[]]
# 1  [[732338.7056828703, 0.0], [732338.7065972222,...
# 2  [[731947.3764930556, 0.0], [731947.8252893519,...
# 3  [[732154.873136574, 0.0], [732154.9181365741, ...
# ...
